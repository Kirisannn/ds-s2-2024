# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ian_file = pd.read_csv(f"assignment04_Ian/src/output/scaleTest10.csv")
ian_res = pd.DataFrame(columns=["No. of Requests", "Time"])

avg_1 = ian_file["Time"].mean()

# New row data as a DataFrame
new_rows = pd.DataFrame({
    "No. of Requests": 10,
    "Time": avg_1
})
ian_res = pd.concat([ian_res, new_rows], ignore_index=True)# Loop through files and compute averages, appending to DataFrames
# for i in range(1, 11):
#     ian_file = pd.read_csv(f"assignment04_Ian/src/output/scaleTest10.csv")
#     avg_1 = ian_file["Time"].mean()
#     # print(avg_1)
#     # Assign the appended DataFrame back to ian_res
#     new_row = {"No. of Requests": (i * 10), "Time": avg_1}
#     temp = ian_res.append(new_row)

    # sy_file = pd.read_csv(f"assignment2/output/scaleTest{i*10}.csv")
    # avg_2 = sy_file["Time"].mean()
    # # Assign the appended DataFrame back to sy_res
    # sy_res = sy_res.append({"No. of Requests": i * 10, "Time": avg_2}, ignore_index=True)
# Out:
#   No. of Requests  Time
# 0               5  10.5
# 1              10  20.0
# /tmp/ipykernel_80578/3152925890.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   ian_res = pd.concat([ian_res, new_rows], ignore_index=True)

# %%
print(ian_res)
plt.figure(figsize=(10,6))

# plt.plot(ian_data["number_of_requests"], ian_data["time_taken"], color="green", alpha=0.7, label="Ian")
# plt.plot(shinyi_data["number_of_requests"], shinyi_data["time_taken"], color="purple", alpha=0.7, label="Shin Yi")

plt.xlabel("No. of Requests")
plt.ylabel("Time (ms)")
plt.title("No. of Requests vs Time Taken to Process Requests")
plt.legend()
plt.grid(True)

plt.show()
# Out:
#   No. of Requests  Time
# 0               5  10.5
# 1              10  20.0
# /tmp/ipykernel_80578/457210279.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
